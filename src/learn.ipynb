# %%
import sys
import os
# !sed -i '3 s#^#//#' /etc/apt/apt.conf.d/70debconf 
# !sudo apt update
# !sudo -H pip3 install rosdep rospkg rosinstall_generator rosinstall wstool vcstools
# !git clone https://github.com/catkin/catkin_tools.git && cd catkin_tools && pip3 install -r requirements.txt --upgrade && python setup.py install --record install_manifest.txt 
# !echo "source /usr/local/etc/bash_completion.d/catkin_tools-completion.bash" >> ~/.bashrc && source ~/.bashrc
# !apt-get install python3-empy
# !apt-get update && apt-get install --only-upgrade python3-catkin-pkg
# !apt-get install dialog
os.environ['DEBIAN_FRONTEND']='noninteractive'
# !sudo rosdep init
# !rosdep update
# !sudo rosdep fix-permissions
# !rosdep update
# !git clone https://github.com/shandilya1998/CPGController
os.chdir('/content/CPGController/src/simulations/ws')
# !catkin config --init -DCMAKE_BUILD_TYPE=Release --blacklist rqt_rviz rviz_plugin_tutorials librviz_tutorial gazebo moveit --install
# !rosinstall_generator ros_base --rosdistro melodic --deps --tar > melodic-ros-base.rosinstall
# !wstool init -j8 src melodic-ros-base.rosinstall
os.environ['ROS_PYTHON_VERSION']='3'
# !pip3 install -U -f https://extras.wxpython.org/wxPython4/extras/linux/gtk3/ubuntu-18.04 wxPython
# !printf -- '#/bin/bash\n#Check whether root\nif [ $(whoami) != root ]; then\necho You must be root or use sudo to install packages.\nreturn\nfi\n#Call apt-get for each package\nfor pkg in "$@"\ndo\necho "Installing $pkg"\nsudo apt-get -my install $pkg >> install.log\ndone\n' > install_skip
# !chmod +x install_skip
# !sudo ./install_skip `rosdep check --from-paths src --ignore-src | grep python | sed -e "s/^apt\t//g" | sed -z "s/\n/ /g"`
# !rosdep install --from-paths src --ignore-src -y --skip-keys="`rosdep check --from-paths src --ignore-src | grep python | sed -e "s/^apt\t//g" | sed -z "s/\n/ /g"`"
# !find . -type f -exec sed -i 's/\/usr\/bin\/env[ ]*python/\/usr\/bin\/env python3/g' {} +
# !catkin clean -y
# !catkin build
sys.path.insert(2, '/content/CPGController/src/simulations/ws/install/lib/python3/dist-packages')
for path in sys.path:
    if path:
        if 'dist-packages' in path:
            os.environ['PYTHONPATH'] += ':{path}'.format(path = path)
# !source install/setup.bash
os.chdir('/content/CPGController/src')
os.environ['PATH'] += ':/content/CPGController/src/simulations/ws/install/bin'
os.environ['ROS_PACKAGE_PATH']='/content/CPGController/src/simulations/ws/src'
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [49.0 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,929 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,391 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,732 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,360 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,162 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [886 kB]
# Fetched 10.8 MB in 3s (4,228 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 33 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Collecting rosdep
#   Downloading https://files.pythonhosted.org/packages/b9/6a/67afeb7640d66f92446bf5fa2920f1fb86a11d784f0d7063dd8da31d39a3/rosdep-0.20.0-py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 4.2MB/s
# Collecting rospkg
#   Downloading https://files.pythonhosted.org/packages/67/73/5d5bb03c0d75dc0c4cea8c58ab42f7ca4e1fd50ec67156c48586a32be842/rospkg-1.2.10-py3-none-any.whl
# Collecting rosinstall_generator
#   Downloading https://files.pythonhosted.org/packages/95/32/12c47a4bfc47dd648f8446cd8bc7e634422092dcd9c7bca07ec250010e61/rosinstall_generator-0.1.22-py3-none-any.whl
# Collecting rosinstall
#   Downloading https://files.pythonhosted.org/packages/38/c5/2c466034d05ad84ca15179d1f496958c6caad9432928bf7436711cc3e64e/rosinstall-0.7.8.tar.gz
# Collecting wstool
#   Downloading https://files.pythonhosted.org/packages/66/7b/a3e4195605644e54658101acc13593703bde9fb67731e4565ac225a5bdb5/wstool-0.1.17.tar.gz (53kB)
#      |████████████████████████████████| 61kB 3.8MB/s
# Collecting vcstools
#   Downloading https://files.pythonhosted.org/packages/30/4a/a3ee59bd58ea68d1d33693c310c7f44206d53f1e17e9cab815273589503e/vcstools-0.1.42-py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 3.5MB/s
# Requirement already satisfied: PyYAML>=3.1 in /usr/local/lib/python3.6/dist-packages (from rosdep) (3.13)
# Collecting catkin-pkg>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/32/36/4e418a15c6b0334503f57ff59ccb11a7a3f99c5937d725846110ae1c752d/catkin_pkg-0.4.23-py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 4.7MB/s
# Collecting rosdistro>=0.7.5
#   Downloading https://files.pythonhosted.org/packages/8e/d2/9edf2b1ee6d9e762ca136eff03c9f4883d5d00d330946cbb2897adb3395f/rosdistro-0.8.3-py3-none-any.whl (92kB)
#      |████████████████████████████████| 102kB 5.1MB/s
# Collecting distro
#   Downloading https://files.pythonhosted.org/packages/25/b7/b3c4270a11414cb22c6352ebc7a83aaa3712043be29daa05018fd5a5c956/distro-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from rosinstall_generator) (53.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from vcstools) (2.8.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from catkin-pkg>=0.4.0->rosdep) (2.4.7)
# Requirement already satisfied: docutils in /usr/local/lib/python3.6/dist-packages (from catkin-pkg>=0.4.0->rosdep) (0.16)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->vcstools) (1.15.0)
# Building wheels for collected packages: rosinstall, wstool
#   Building wheel for rosinstall (setup.py) ... done
#   Created wheel for rosinstall: filename=rosinstall-0.7.8-cp36-none-any.whl size=41351 sha256=49c998e88c00ca8fc4dcff70708eea6f8d1f0b2f90d3abf1ef422e22dbcfec21
#   Stored in directory: /root/.cache/pip/wheels/38/66/cc/45f49c8b98b8305b5682fdf9494dcfae7d20869789a925dda4
#   Building wheel for wstool (setup.py) ... done
#   Created wheel for wstool: filename=wstool-0.1.17-py2.py3-none-any.whl size=63589 sha256=7d2b8bbc3823b204655a628c48f7bf89ba2dbb7a31ad2f684064e9892d4c8294
#   Stored in directory: /root/.cache/pip/wheels/1d/64/85/9ec2a0b901fb79b33b1a438d38e9e60b62ffd0ec31baf022ac
# Successfully built rosinstall wstool
# Installing collected packages: catkin-pkg, distro, rospkg, rosdistro, rosdep, rosinstall-generator, vcstools, wstool, rosinstall
# Successfully installed catkin-pkg-0.4.23 distro-1.5.0 rosdep-0.20.0 rosdistro-0.8.3 rosinstall-0.7.8 rosinstall-generator-0.1.22 rospkg-1.2.10 vcstools-0.1.42 wstool-0.1.17
# Cloning into 'catkin_tools'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 4495 (delta 38), reused 24 (delta 13), pack-reused 4416
# Receiving objects: 100% (4495/4495), 1.93 MiB | 19.60 MiB/s, done.
# Resolving deltas: 100% (2973/2973), done.
# Requirement already up-to-date: catkin_pkg in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 1)) (0.4.23)
# Collecting osrf_pycommon
#   Downloading https://files.pythonhosted.org/packages/c4/15/db1a7ce49f3144f5438565bd83735f622095e29b5d5cb28d13bafaa1bbcb/osrf_pycommon-0.1.9-py3-none-any.whl
# Collecting pyyaml
#   Downloading https://files.pythonhosted.org/packages/7a/5b/bc0b5ab38247bba158504a410112b6c03f153c652734ece1849749e5f518/PyYAML-5.4.1-cp36-cp36m-manylinux1_x86_64.whl (640kB)
#      |████████████████████████████████| 645kB 6.7MB/s
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 4)) (53.0.0)
# Collecting sphinxcontrib-programoutput
#   Downloading https://files.pythonhosted.org/packages/53/af/a182c20b343c14adb1e9b98e3b5cec58ba61e3e00156dd7195775df0d094/sphinxcontrib_programoutput-0.16-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: python-dateutil in /usr/local/lib/python3.6/dist-packages (from catkin_pkg->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing in /usr/local/lib/python3.6/dist-packages (from catkin_pkg->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied, skipping upgrade: docutils in /usr/local/lib/python3.6/dist-packages (from catkin_pkg->-r requirements.txt (line 1)) (0.16)
# Requirement already satisfied, skipping upgrade: Sphinx>=1.7.0 in /usr/local/lib/python3.6/dist-packages (from sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.8.5)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->catkin_pkg->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied, skipping upgrade: alabaster<0.8,>=0.7 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (0.7.12)
# Requirement already satisfied, skipping upgrade: imagesize in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.23.0)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.3 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.11.3)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (20.9)
# Requirement already satisfied, skipping upgrade: Pygments>=2.0 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.6.1)
# Requirement already satisfied, skipping upgrade: babel!=2.0,>=1.3 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.9.0)
# Requirement already satisfied, skipping upgrade: sphinxcontrib-websupport in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.2.4)
# Requirement already satisfied, skipping upgrade: snowballstemmer>=1.1 in /usr/local/lib/python3.6/dist-packages (from Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2020.12.5)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.3->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied, skipping upgrade: pytz>=2015.7 in /usr/local/lib/python3.6/dist-packages (from babel!=2.0,>=1.3->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (2018.9)
# Requirement already satisfied, skipping upgrade: sphinxcontrib-serializinghtml in /usr/local/lib/python3.6/dist-packages (from sphinxcontrib-websupport->Sphinx>=1.7.0->sphinxcontrib-programoutput->-r requirements.txt (line 5)) (1.1.4)
# Installing collected packages: osrf-pycommon, pyyaml, sphinxcontrib-programoutput
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed osrf-pycommon-0.1.9 pyyaml-5.4.1 sphinxcontrib-programoutput-0.16
# running install
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/catkin_tools
# copying catkin_tools/metadata.py -> build/lib/catkin_tools
# copying catkin_tools/argument_parsing.py -> build/lib/catkin_tools
# copying catkin_tools/utils.py -> build/lib/catkin_tools
# copying catkin_tools/context.py -> build/lib/catkin_tools
# copying catkin_tools/config.py -> build/lib/catkin_tools
# copying catkin_tools/terminal_color.py -> build/lib/catkin_tools
# copying catkin_tools/__init__.py -> build/lib/catkin_tools
# copying catkin_tools/common.py -> build/lib/catkin_tools
# copying catkin_tools/resultspace.py -> build/lib/catkin_tools
# creating build/lib/catkin_tools/notifications
# copying catkin_tools/notifications/__init__.py -> build/lib/catkin_tools/notifications
# copying catkin_tools/notifications/impl.py -> build/lib/catkin_tools/notifications
# creating build/lib/catkin_tools/jobs
# copying catkin_tools/jobs/catkin.py -> build/lib/catkin_tools/jobs
# copying catkin_tools/jobs/utils.py -> build/lib/catkin_tools/jobs
# copying catkin_tools/jobs/output.py -> build/lib/catkin_tools/jobs
# copying catkin_tools/jobs/__init__.py -> build/lib/catkin_tools/jobs
# copying catkin_tools/jobs/cmake.py -> build/lib/catkin_tools/jobs
# creating build/lib/catkin_tools/commands
# copying catkin_tools/commands/catkin.py -> build/lib/catkin_tools/commands
# copying catkin_tools/commands/__init__.py -> build/lib/catkin_tools/commands
# creating build/lib/catkin_tools/verbs
# copying catkin_tools/verbs/__init__.py -> build/lib/catkin_tools/verbs
# creating build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/devel.py -> build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/source.py -> build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/build.py -> build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/install.py -> build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/__init__.py -> build/lib/catkin_tools/spaces
# copying catkin_tools/spaces/log.py -> build/lib/catkin_tools/spaces
# creating build/lib/catkin_tools/execution
# copying catkin_tools/execution/events.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/stages.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/job_server.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/jobs.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/executor.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/__init__.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/controllers.py -> build/lib/catkin_tools/execution
# copying catkin_tools/execution/io.py -> build/lib/catkin_tools/execution
# creating build/lib/catkin_tools/jobs/commands
# copying catkin_tools/jobs/commands/make.py -> build/lib/catkin_tools/jobs/commands
# copying catkin_tools/jobs/commands/__init__.py -> build/lib/catkin_tools/jobs/commands
# copying catkin_tools/jobs/commands/cmake.py -> build/lib/catkin_tools/jobs/commands
# creating build/lib/catkin_tools/verbs/catkin_build
# copying catkin_tools/verbs/catkin_build/build.py -> build/lib/catkin_tools/verbs/catkin_build
# copying catkin_tools/verbs/catkin_build/cli.py -> build/lib/catkin_tools/verbs/catkin_build
# copying catkin_tools/verbs/catkin_build/color.py -> build/lib/catkin_tools/verbs/catkin_build
# copying catkin_tools/verbs/catkin_build/__init__.py -> build/lib/catkin_tools/verbs/catkin_build
# creating build/lib/catkin_tools/verbs/catkin_config
# copying catkin_tools/verbs/catkin_config/cli.py -> build/lib/catkin_tools/verbs/catkin_config
# copying catkin_tools/verbs/catkin_config/__init__.py -> build/lib/catkin_tools/verbs/catkin_config
# creating build/lib/catkin_tools/verbs/catkin_init
# copying catkin_tools/verbs/catkin_init/cli.py -> build/lib/catkin_tools/verbs/catkin_init
# copying catkin_tools/verbs/catkin_init/__init__.py -> build/lib/catkin_tools/verbs/catkin_init
# creating build/lib/catkin_tools/verbs/catkin_list
# copying catkin_tools/verbs/catkin_list/cli.py -> build/lib/catkin_tools/verbs/catkin_list
# copying catkin_tools/verbs/catkin_list/__init__.py -> build/lib/catkin_tools/verbs/catkin_list
# creating build/lib/catkin_tools/verbs/catkin_create
# copying catkin_tools/verbs/catkin_create/cli.py -> build/lib/catkin_tools/verbs/catkin_create
# copying catkin_tools/verbs/catkin_create/__init__.py -> build/lib/catkin_tools/verbs/catkin_create
# creating build/lib/catkin_tools/verbs/catkin_env
# copying catkin_tools/verbs/catkin_env/cli.py -> build/lib/catkin_tools/verbs/catkin_env
# copying catkin_tools/verbs/catkin_env/__init__.py -> build/lib/catkin_tools/verbs/catkin_env
# creating build/lib/catkin_tools/verbs/catkin_locate
# copying catkin_tools/verbs/catkin_locate/cli.py -> build/lib/catkin_tools/verbs/catkin_locate
# copying catkin_tools/verbs/catkin_locate/__init__.py -> build/lib/catkin_tools/verbs/catkin_locate
# creating build/lib/catkin_tools/verbs/catkin_clean
# copying catkin_tools/verbs/catkin_clean/clean.py -> build/lib/catkin_tools/verbs/catkin_clean
# copying catkin_tools/verbs/catkin_clean/cli.py -> build/lib/catkin_tools/verbs/catkin_clean
# copying catkin_tools/verbs/catkin_clean/color.py -> build/lib/catkin_tools/verbs/catkin_clean
# copying catkin_tools/verbs/catkin_clean/__init__.py -> build/lib/catkin_tools/verbs/catkin_clean
# creating build/lib/catkin_tools/verbs/catkin_profile
# copying catkin_tools/verbs/catkin_profile/cli.py -> build/lib/catkin_tools/verbs/catkin_profile
# copying catkin_tools/verbs/catkin_profile/__init__.py -> build/lib/catkin_tools/verbs/catkin_profile
# creating build/lib/catkin_tools/jobs/cmake
# copying catkin_tools/jobs/cmake/python.cmake -> build/lib/catkin_tools/jobs/cmake
# copying catkin_tools/jobs/cmake/python_install_dir.cmake -> build/lib/catkin_tools/jobs/cmake
# creating build/lib/catkin_tools/notifications/resources
# creating build/lib/catkin_tools/notifications/resources/linux
# copying catkin_tools/notifications/resources/linux/catkin_icon.png -> build/lib/catkin_tools/notifications/resources/linux
# copying catkin_tools/notifications/resources/linux/catkin_icon_red.png -> build/lib/catkin_tools/notifications/resources/linux
# copying catkin_tools/verbs/catkin_shell_verbs.bash -> build/lib/catkin_tools/verbs
# creating build/lib/catkin_tools/notifications/resources/osx
# creating build/lib/catkin_tools/notifications/resources/osx/catkin build.app
# creating build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/PkgInfo -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Info.plist -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# creating build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS/catkin build -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS
# creating build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/AppIcon.icns -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/catkin_blue_logo_only.icns -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# creating build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/InfoPlist.strings -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/MainMenu.nib -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/Credits.rtf -> build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# running install_lib
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS/catkin build -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/PkgInfo -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Info.plist -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/InfoPlist.strings -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/MainMenu.nib -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/Credits.rtf -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/AppIcon.icns -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# copying build/lib/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/catkin_blue_logo_only.icns -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/linux
# copying build/lib/catkin_tools/notifications/resources/linux/catkin_icon_red.png -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/linux
# copying build/lib/catkin_tools/notifications/resources/linux/catkin_icon.png -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/linux
# copying build/lib/catkin_tools/notifications/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications
# copying build/lib/catkin_tools/notifications/impl.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands
# copying build/lib/catkin_tools/jobs/commands/make.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands
# copying build/lib/catkin_tools/jobs/commands/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands
# copying build/lib/catkin_tools/jobs/commands/cmake.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands
# copying build/lib/catkin_tools/jobs/catkin.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# copying build/lib/catkin_tools/jobs/utils.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# copying build/lib/catkin_tools/jobs/output.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# copying build/lib/catkin_tools/jobs/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# copying build/lib/catkin_tools/jobs/cmake.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake
# copying build/lib/catkin_tools/jobs/cmake/python.cmake -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake
# copying build/lib/catkin_tools/jobs/cmake/python_install_dir.cmake -> /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake
# copying build/lib/catkin_tools/metadata.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/commands
# copying build/lib/catkin_tools/commands/catkin.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/commands
# copying build/lib/catkin_tools/commands/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/commands
# copying build/lib/catkin_tools/argument_parsing.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build
# copying build/lib/catkin_tools/verbs/catkin_build/build.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build
# copying build/lib/catkin_tools/verbs/catkin_build/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build
# copying build/lib/catkin_tools/verbs/catkin_build/color.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build
# copying build/lib/catkin_tools/verbs/catkin_build/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config
# copying build/lib/catkin_tools/verbs/catkin_config/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config
# copying build/lib/catkin_tools/verbs/catkin_config/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init
# copying build/lib/catkin_tools/verbs/catkin_init/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init
# copying build/lib/catkin_tools/verbs/catkin_init/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list
# copying build/lib/catkin_tools/verbs/catkin_list/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list
# copying build/lib/catkin_tools/verbs/catkin_list/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create
# copying build/lib/catkin_tools/verbs/catkin_create/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create
# copying build/lib/catkin_tools/verbs/catkin_create/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env
# copying build/lib/catkin_tools/verbs/catkin_env/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env
# copying build/lib/catkin_tools/verbs/catkin_env/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env
# copying build/lib/catkin_tools/verbs/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate
# copying build/lib/catkin_tools/verbs/catkin_locate/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate
# copying build/lib/catkin_tools/verbs/catkin_locate/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean
# copying build/lib/catkin_tools/verbs/catkin_clean/clean.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean
# copying build/lib/catkin_tools/verbs/catkin_clean/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean
# copying build/lib/catkin_tools/verbs/catkin_clean/color.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean
# copying build/lib/catkin_tools/verbs/catkin_clean/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean
# copying build/lib/catkin_tools/verbs/catkin_shell_verbs.bash -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile
# copying build/lib/catkin_tools/verbs/catkin_profile/cli.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile
# copying build/lib/catkin_tools/verbs/catkin_profile/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile
# copying build/lib/catkin_tools/utils.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/devel.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/source.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/build.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/install.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/spaces/log.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces
# copying build/lib/catkin_tools/context.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# copying build/lib/catkin_tools/config.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# copying build/lib/catkin_tools/terminal_color.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# copying build/lib/catkin_tools/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# creating /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/events.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/stages.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/job_server.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/jobs.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/executor.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/__init__.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/controllers.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/execution/io.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools/execution
# copying build/lib/catkin_tools/common.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# copying build/lib/catkin_tools/resultspace.py -> /usr/local/lib/python3.6/dist-packages/catkin_tools
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/impl.py to impl.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/make.py to make.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/cmake.py to cmake.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/catkin.py to catkin.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/utils.py to utils.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/output.py to output.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake.py to cmake.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/metadata.py to metadata.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/commands/catkin.py to catkin.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/commands/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/argument_parsing.py to argument_parsing.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/build.py to build.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/color.py to color.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/clean.py to clean.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/color.py to color.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile/cli.py to cli.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/utils.py to utils.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/devel.py to devel.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/source.py to source.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/build.py to build.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/install.py to install.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/log.py to log.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/context.py to context.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/config.py to config.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/terminal_color.py to terminal_color.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/events.py to events.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/stages.py to stages.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/job_server.py to job_server.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/jobs.py to jobs.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/executor.py to executor.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/__init__.py to __init__.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/controllers.py to controllers.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/io.py to io.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/common.py to common.cpython-36.pyc
# byte-compiling /usr/local/lib/python3.6/dist-packages/catkin_tools/resultspace.py to resultspace.cpython-36.pyc
# running install_data
# copying completion/catkin_tools-completion.bash -> /etc/bash_completion.d
# creating /usr/share/zsh/site-functions
# copying completion/_catkin -> /usr/share/zsh/site-functions
# running install_egg_info
# running egg_info
# creating catkin_tools.egg-info
# writing catkin_tools.egg-info/PKG-INFO
# writing dependency_links to catkin_tools.egg-info/dependency_links.txt
# writing entry points to catkin_tools.egg-info/entry_points.txt
# writing requirements to catkin_tools.egg-info/requires.txt
# writing top-level names to catkin_tools.egg-info/top_level.txt
# writing manifest file 'catkin_tools.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'catkin_tools.egg-info/SOURCES.txt'
# Copying catkin_tools.egg-info to /usr/local/lib/python3.6/dist-packages/catkin_tools-0.5.0-py3.6.egg-info
# running install_scripts
# Installing catkin script to /usr/local/bin
# writing list of installed files to 'install_manifest.txt'
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/metadata.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/argument_parsing.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/utils.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/context.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/config.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/terminal_color.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/common.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/resultspace.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/impl.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/catkin.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/utils.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/output.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/commands/catkin.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/commands/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/devel.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/source.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/build.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/install.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/spaces/log.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/events.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/stages.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/job_server.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/jobs.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/executor.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/controllers.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/execution/io.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/make.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/commands/cmake.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/build.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/color.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_build/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_config/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_init/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_list/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_create/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_env/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_locate/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/clean.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/color.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_clean/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile/cli.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_profile/__init__.py to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake/python.cmake to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/jobs/cmake/python_install_dir.cmake to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/linux/catkin_icon.png to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/linux/catkin_icon_red.png to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/verbs/catkin_shell_verbs.bash to 755
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/PkgInfo to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Info.plist to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/MacOS/catkin build to 755
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/AppIcon.icns to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/catkin_blue_logo_only.icns to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/InfoPlist.strings to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/MainMenu.nib to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/resources/osx/catkin build.app/Contents/Resources/en.lproj/Credits.rtf to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/metadata.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/argument_parsing.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/utils.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/context.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/config.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/terminal_color.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/__init__.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/common.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/__pycache__/resultspace.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/__pycache__/__init__.cpython-36.pyc to 644
# changing permissions of /usr/local/lib/python3.6/dist-packages/catkin_tools/notifications/__pycache__/impl.cpython-36.pyc to 644
# ...
# Starting  >>> genpy
# Finished  <<< gennodejs                            [ 7.1 seconds ]
# Starting  >>> cpp_common
# Finished  <<< genpy                                [ 7.8 seconds ]
# Starting  >>> message_generation
# Finished  <<< cpp_common                           [ 8.3 seconds ]
# Starting  >>> ros_environment
# Finished  <<< message_generation                   [ 5.4 seconds ]
# Starting  >>> rosbag_migration_rule
# Finished  <<< ros_environment                      [ 8.0 seconds ]
# Starting  >>> rosboost_cfg
# Finished  <<< rosbag_migration_rule                [ 5.4 seconds ]
# Starting  >>> rosclean
# Finished  <<< rosboost_cfg                         [ 7.7 seconds ]
# Starting  >>> rosgraph
# Finished  <<< rosclean                             [ 7.8 seconds ]
# Starting  >>> roslang
# Finished  <<< rosgraph                             [ 7.0 seconds ]
# Starting  >>> rosmake
# Finished  <<< roslang                              [ 5.7 seconds ]
# Starting  >>> rosmaster
# _______________________________________________________________________________
# Warnings   << rosmake:install /content/CPGController/src/simulations/ws/logs/rosmake/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/rosmake; catkin build --get-env rosmake | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< rosmake                              [ 7.5 seconds ]
# Starting  >>> rospack
# Finished  <<< rosmaster                            [ 6.8 seconds ]
# Starting  >>> rosparam
# Finished  <<< rosparam                             [ 6.9 seconds ]
# Starting  >>> rostime
# Finished  <<< rostime                              [ 14.7 seconds ]
# Starting  >>> roscpp_traits
# Finished  <<< roscpp_traits                        [ 5.8 seconds ]
# Starting  >>> roscpp_serialization
# Finished  <<< rospack                              [ 30.3 seconds ]
# Starting  >>> rosbash
# Finished  <<< roscpp_serialization                 [ 7.4 seconds ]
# Starting  >>> message_runtime
# Finished  <<< rosbash                              [ 7.3 seconds ]
# Starting  >>> roscpp_core
# Finished  <<< message_runtime                      [ 5.8 seconds ]
# Starting  >>> rosbuild
# Finished  <<< roscpp_core                          [ 5.2 seconds ]
# Starting  >>> roslib
# Finished  <<< rosbuild                             [ 6.6 seconds ]
# Starting  >>> mk
# Finished  <<< mk                                   [ 5.9 seconds ]
# Starting  >>> smclib
# _______________________________________________________________________________
# Warnings   << roslib:install /content/CPGController/src/simulations/ws/logs/roslib/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/roslib; catkin build --get-env roslib | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< roslib                               [ 13.8 seconds ]
# Starting  >>> roscreate
# _______________________________________________________________________________
# Warnings   << smclib:install /content/CPGController/src/simulations/ws/logs/smclib/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/smclib; catkin build --get-env smclib | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< smclib                               [ 7.8 seconds ]
# Starting  >>> rosunit
# _______________________________________________________________________________
# Warnings   << roscreate:install /content/CPGController/src/simulations/ws/logs/roscreate/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/roscreate; catkin build --get-env roscreate | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< roscreate                            [ 8.0 seconds ]
# Starting  >>> std_msgs
# Finished  <<< rosunit                              [ 8.1 seconds ]
# Starting  >>> ros
# Finished  <<< ros                                  [ 5.3 seconds ]
# Starting  >>> rosconsole
# Finished  <<< rosconsole                           [ 23.1 seconds ]
# Starting  >>> pluginlib
# Finished  <<< std_msgs                             [ 55.2 seconds ]
# Starting  >>> rosconsole_bridge
# Finished  <<< pluginlib                            [ 17.3 seconds ]
# Starting  >>> roslz4
# Finished  <<< rosconsole_bridge                    [ 10.7 seconds ]
# Starting  >>> actionlib_msgs
# Finished  <<< roslz4                               [ 9.5 seconds ]
# Starting  >>> bond
# Finished  <<< bond                                 [ 10.8 seconds ]
# Starting  >>> diagnostic_msgs
# Finished  <<< actionlib_msgs                       [ 12.2 seconds ]
# Starting  >>> geometry_msgs
# Finished  <<< diagnostic_msgs                      [ 15.5 seconds ]
# Starting  >>> rosgraph_msgs
# Finished  <<< rosgraph_msgs                        [ 12.3 seconds ]
# Starting  >>> std_srvs
# Finished  <<< std_srvs                             [ 12.4 seconds ]
# Starting  >>> roslisp
# Finished  <<< geometry_msgs                        [ 45.5 seconds ]
# Starting  >>> nav_msgs
# Finished  <<< roslisp                              [ 6.6 seconds ]
# Starting  >>> shape_msgs
# Finished  <<< shape_msgs                           [ 14.6 seconds ]
# Starting  >>> trajectory_msgs
# Finished  <<< nav_msgs                             [ 28.5 seconds ]
# Starting  >>> visualization_msgs
# Finished  <<< trajectory_msgs                      [ 14.2 seconds ]
# Starting  >>> xmlrpcpp
# Finished  <<< visualization_msgs                   [ 23.1 seconds ]
# Finished  <<< xmlrpcpp                             [ 15.0 seconds ]
# Starting  >>> roscpp
# Finished  <<< roscpp                               [ 2 minutes and 36.0 seconds ]
# Starting  >>> rospy
# Starting  >>> bondcpp
# Finished  <<< rospy                                [ 7.4 seconds ]
# Starting  >>> bondpy
# Finished  <<< bondcpp                              [ 15.5 seconds ]
# Starting  >>> nodelet
# _______________________________________________________________________________
# Warnings   << bondpy:install /content/CPGController/src/simulations/ws/logs/bondpy/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/bondpy; catkin build --get-env bondpy | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< bondpy                               [ 8.5 seconds ]
# Starting  >>> bond_core
# Finished  <<< bond_core                            [ 5.8 seconds ]
# Starting  >>> quadruped
# Finished  <<< quadruped                            [ 6.3 seconds ]
# Starting  >>> quadruped_description
# Finished  <<< nodelet                              [ 34.9 seconds ]
# Starting  >>> rosout
# Finished  <<< quadruped_description                [ 5.8 seconds ]
# Finished  <<< rosout                               [ 9.1 seconds ]
# Starting  >>> roslaunch
# Finished  <<< roslaunch                            [ 5.6 seconds ]
# Starting  >>> rostest
# Finished  <<< rostest                              [ 6.1 seconds ]
# Starting  >>> message_filters
# Starting  >>> rosbag_storage
# Finished  <<< message_filters                      [ 11.4 seconds ]
# Starting  >>> topic_tools
# Finished  <<< topic_tools                          [ 1 minute and 2.4 seconds ]
# Finished  <<< rosbag_storage                       [ 1 minute and 19.6 seconds ]
# Starting  >>> rosbag
# Finished  <<< rosbag                               [ 41.0 seconds ]
# Starting  >>> rosmsg
# Starting  >>> rostopic
# Finished  <<< rostopic                             [ 7.2 seconds ]
# Starting  >>> rosnode
# Finished  <<< rosmsg                               [ 7.5 seconds ]
# Starting  >>> rosservice
# Finished  <<< rosnode                              [ 7.4 seconds ]
# Starting  >>> actionlib
# Finished  <<< rosservice                           [ 7.3 seconds ]
# Starting  >>> dynamic_reconfigure
# Finished  <<< dynamic_reconfigure                  [ 29.3 seconds ]
# Starting  >>> nodelet_topic_tools
# Finished  <<< actionlib                            [ 43.6 seconds ]
# Starting  >>> roswtf
# Finished  <<< nodelet_topic_tools                  [ 6.9 seconds ]
# Starting  >>> nodelet_core
# Finished  <<< nodelet_core                         [ 5.4 seconds ]
# Starting  >>> sensor_msgs
# Finished  <<< roswtf                               [ 7.5 seconds ]
# Starting  >>> ros_comm
# Finished  <<< ros_comm                             [ 6.1 seconds ]
# _______________________________________________________________________________
# Warnings   << sensor_msgs:install /content/CPGController/src/simulations/ws/logs/sensor_msgs/build.install.000.log
# /usr/local/lib/python3.6/dist-packages/setuptools/dist.py:125: UserWarning: newlines not allowed and will break in the future
#   warnings.warn("newlines not allowed and will break in the future")
# cd /content/CPGController/src/simulations/ws/build/sensor_msgs; catkin build --get-env sensor_msgs | catkin env -si  /usr/bin/make install; cd -
# ...............................................................................
# Finished  <<< sensor_msgs                          [ 30.8 seconds ]
# Starting  >>> stereo_msgs
# Finished  <<< stereo_msgs                          [ 6.5 seconds ]
# Starting  >>> common_msgs
# Finished  <<< common_msgs                          [ 3.8 seconds ]
# Starting  >>> ros_core
# Finished  <<< ros_core                             [ 3.8 seconds ]
# Starting  >>> ros_base
# Finished  <<< ros_base                             [ 3.7 seconds ]
# [build] Summary: All 81 packages succeeded!
# [build]   Ignored:   None.
# [build]   Warnings:  6 packages succeeded with warnings.
# [build]   Abandoned: None.
# [build]   Failed:    None.
# [build] Runtime: 13 minutes and 1.7 seconds total.
# [build] Note: Workspace packages have changed, please re-source setup files to use them.
